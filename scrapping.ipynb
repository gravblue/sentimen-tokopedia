# %% [markdown]
# ## Import Library

# %%
# !pip install google-play-scraper

from google_play_scraper import app, reviews, Sort
import pandas as pd
import csv
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.7-py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 1.4 MB/s eta 0:00:00
# Downloading google_play_scraper-1.2.7-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.7

# %% [markdown]
# ## Scraping Dataset

# %%
scrapreview, _ = reviews(
    'com.tokopedia.tkpd',
    lang='id',
    country='id',
    sort=Sort.NEWEST,
    count=30000
)

# %%
# Menyimpan ulasan dalam file CSV
with open('tokopedia_reviews.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['Review'])
    for review in scrapreview:
        writer.writerow([review['content']])

# %% [markdown]
# ## Loading Dataset

# %%
app_reviews_df = pd.DataFrame(scrapreview)
app_reviews_df.shape
app_reviews_df.head()
app_reviews_df.to_csv('tokopedia_reviews.csv', index=False)

# Membuat DataFrame dari hasil scrapreview
app_reviews_df = pd.DataFrame(scrapreview)

# Menghitung jumlah baris dan kolom dalam DataFrame
jumlah_ulasan, jumlah_kolom = app_reviews_df.shape
print(f'Jumlah ulasan: {jumlah_ulasan}')
print(f'Jumlah kolom: {jumlah_kolom}')
# Out:
# Jumlah ulasan: 30000
# Jumlah kolom: 11

# %%
# Menampilkan lima baris pertama
app_reviews_df.head()
# Out:
#                                reviewId         userName  \
# 0  88191a7f-5073-4605-8af9-1c5fe82563ff  Pengguna Google
# 1  4131830a-ce4b-4089-9567-0a445addec39  Pengguna Google
# 2  a451d7cb-b673-4271-83cc-5e9d94a18c97  Pengguna Google
# 3  fabd6bcd-cb6d-40ee-ab28-9afad9d6c46a  Pengguna Google
# 4  cb5eaed0-6afb-4848-8b3f-78384c8003fb  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0                       Ini sangat berguna buat saya      5              0
# 1                                             mantap      5              0
# 2  sudah tidak berpihak lagi sama rakyat kecil,ve...      1              0
# 3                                               suka      5              0
# 4                                         mantaaappp      5              0
#
#   reviewCreatedVersion                  at replyContent repliedAt appVersion
# 0                 None 2025-10-12 15:53:55         None       NaT       None
# 1                 None 2025-10-12 15:41:48         None       NaT       None
# 2              3.333.0 2025-10-12 15:23:58         None       NaT    3.333.0
# 3              3.333.0 2025-10-12 15:15:11         None       NaT    3.333.0
# 4              3.333.0 2025-10-12 15:09:27         None       NaT    3.333.0
